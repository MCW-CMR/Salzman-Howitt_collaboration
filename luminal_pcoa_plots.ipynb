# %% [markdown]
# # Make luminal PCoA plots

# %%
#import libraries
import pandas as pd
import numpy as np 
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
#import seaborn as sns

# %%
#create figure
my_dpi = 300
plt.figure(figsize=(12, 6), dpi=my_dpi)

# %%
#load data and make df
df = pd.read_csv("exported_bray_pcoa_results/bray_pcoa_data.csv", index_col=0)
df
# Out:
#                 PC1       PC2       PC3 Group   color
# SampleID
# LF247_C1   0.141011  0.149323  0.070724   PBS    blue
# LF247_C10 -0.247946 -0.080272  0.168102   PBS    blue
# LF247_C11  0.216507  0.153253 -0.234977  IL25  yellow
# LF247_C12 -0.267879 -0.009287 -0.083822  IL25  yellow
# LF247_C13 -0.224029  0.068662 -0.057603  IL25  yellow
# LF247_C14 -0.349010 -0.109723 -0.080690  IL25  yellow
# LF247_C16  0.172260 -0.131505 -0.192339  IL25  yellow
# LF247_C17 -0.269586 -0.084354 -0.125806  IL25  yellow
# LF247_C18  0.309546 -0.074730 -0.156712  IL25  yellow
# LF247_C19 -0.380771 -0.135364  0.116292  IL25  yellow
# LF247_C2   0.167930  0.084758  0.101989   PBS    blue
# LF247_C20 -0.151203  0.452792  0.050162  IL25  yellow
# LF247_C3   0.141796  0.119771  0.018748   PBS    blue
# LF247_C4   0.087173 -0.119610  0.054169   PBS    blue
# LF247_C5   0.090454 -0.097059 -0.059148   PBS    blue
# LF247_C6   0.323520 -0.051159  0.050838   PBS    blue
# LF247_C7  -0.260578 -0.000478  0.029459   PBS    blue
# LF247_C8   0.136563  0.026263  0.130443   PBS    blue
# LF247_C9   0.364242 -0.161280  0.200170   PBS    blue

# %%
#initialize plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
marker = {0:'*',1:'.'}
ax.scatter(df['PC1'], df['PC3'], df['PC2'], c=df['color'], depthshade=False, s=60, edgecolor='black')
# label the axes
ax.grid(False)
ax.view_init(15, 65)
ax.set_xlabel("PC1 (51.86%)")
ax.set_zlabel("PC2 (18.28%)")
ax.set_ylabel("PC3 (12.73%)")
#legend
blue_dot = plt.Line2D([], [], color="blue", ls="", marker='.', markersize=15, label = "PBS")
yellow_dot = plt.Line2D([], [], color="yellow", ls="", marker='.', markersize=15, label = "IL25")
#green_dot = mpatches.Patch(color="darkgreen", label = "pre-op")
#yellow_dot = mpatches.Patch(color="yellow", label = "post 3m")

plt.legend(handles=[blue_dot, yellow_dot], loc='upper left', bbox_to_anchor=(0.7, 1))#
#plt.show()
plt.savefig('bray_pcoa_luminal.png', format='png', dpi = 500, bbox_inches="tight")

# %%
#load data and make df
df_weighted = pd.read_csv("exported_weighted_unifrac_pcoa_results/weighted_pcoa_data.csv", index_col=0)
df_weighted
# Out:
#                 PC1       PC2       PC3 Group   color
# SampleID
# LF247_C1   0.077652  0.062426  0.014716   PBS    blue
# LF247_C10 -0.144473 -0.042788  0.054073   PBS    blue
# LF247_C11  0.121696  0.011169 -0.056498  IL25  yellow
# LF247_C12 -0.168686  0.006249 -0.023390  IL25  yellow
# LF247_C13 -0.142651  0.062658 -0.003572  IL25  yellow
# LF247_C14 -0.206473 -0.055951 -0.020042  IL25  yellow
# LF247_C16  0.130514 -0.034599 -0.054467  IL25  yellow
# LF247_C17 -0.177625 -0.016751 -0.033231  IL25  yellow
# LF247_C18  0.201265 -0.029939 -0.047061  IL25  yellow
# LF247_C19 -0.207549 -0.069094  0.032427  IL25  yellow
# LF247_C2   0.093885  0.057005  0.042276   PBS    blue
# LF247_C20 -0.105458  0.102339 -0.000888  IL25  yellow
# LF247_C3   0.087260  0.051496 -0.008802   PBS    blue
# LF247_C4   0.054850 -0.016958  0.014770   PBS    blue
# LF247_C5   0.063778 -0.023396 -0.029614   PBS    blue
# LF247_C6   0.185510 -0.029280  0.006192   PBS    blue
# LF247_C7  -0.157569 -0.005286 -0.004828   PBS    blue
# LF247_C8   0.076591  0.045304  0.052634   PBS    blue
# LF247_C9   0.217483 -0.074602  0.065305   PBS    blue

# %%
#initialize plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
marker = {0:'*',1:'.'}
ax.scatter(df_weighted['PC1'], df_weighted['PC3'], df_weighted['PC2'], c=df_weighted['color'], 
           depthshade=False, s=60, edgecolor='black')
# label the axes
ax.grid(False)
ax.view_init(15, 65)
ax.set_xlabel("PC1 (81.88%)")
ax.set_zlabel("PC2 (9.10%)")
ax.set_ylabel("PC3 (4.90%)")
#legend
blue_dot = plt.Line2D([], [], color="blue", ls="", marker='.', markersize=15, label = "PBS")
yellow_dot = plt.Line2D([], [], color="yellow", ls="", marker='.', markersize=15, label = "IL25")
#green_dot = mpatches.Patch(color="darkgreen", label = "pre-op")
#yellow_dot = mpatches.Patch(color="yellow", label = "post 3m")

plt.legend(handles=[blue_dot, yellow_dot], loc='upper left', bbox_to_anchor=(0.7, 1))#
#plt.show()
plt.savefig('weighted_pcoa_luminal.png', format='png', dpi = 500, bbox_inches="tight")
